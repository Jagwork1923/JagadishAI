# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagwork1923/JagadishAI/blob/main/Graph_Plotting_with_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install matplotlib
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
x = np.array([0,10])
y = np.array([0,20])

# %%
x
# Out:
# array([ 0, 10])

# %%
y
# Out:
# array([ 0, 20])

# %%
plt.plot(x,y)
plt.show()

# %%
#labels
plt.xlabel("Freq")
plt.ylabel("Count")
plt.plot(x,y)
plt.show()

# %%
#labels | Points
plt.xlabel("Freq")
plt.ylabel("Count")
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([0,10,20,30,40,50])
y = np.array([0,20,40,60,80,100])

# %%
x.shape
# Out:
# (6,)

# %%
y.shape
# Out:
# (6,)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'o')
plt.show()

# %%
x = [10,20,30,40,50]
y = [40,40,40,40,40]

# %%
plt.plot(x,y)
plt.show()

# %%
y = np.array([0,20,40,60,80,100])

# %%
plt.plot(y)

# %%
y = np.array([0,204,404,60,802,100])

# %%
plt.plot(y)

# %%
plt.plot(y, marker ='o')

# %%
plt.plot(y, marker ='o', ms = 20)

# %%
plt.plot(y, marker ='o', ms = 20, mec = 'g')

# %%
plt.plot(y, marker ='o', ms = 20, mec = 'r', mfc = 'g')
#

# %%
plt.plot(y, marker ='o', ms = 20, mec = 'r', mfc = 'g', ls = '--')

# %%
plt.plot(y, marker = '*')

# %%
plt.plot(y, 'o:r')

# %%
plt.plot(y, 'o:b')

# %%
plt.plot(y, 'o:r', label = 'First')

# %%
plt.plot(y, '+:b')

# %%
plt.plot(y, '+:b',ms = 15)

# %%
plt.plot(y, 'o:b',ms = 15)

# %%
plt.plot(y, 'o:b',ms = 15, mec = 'orange')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>
